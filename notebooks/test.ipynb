# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
image_path='/data/'

# %%
img=plt.imread(r"C:\ProjectFiles\cnn-image-retrieval\data\images\1163.jpg")

# %%
plt.imshow(img)

# %%
img_csv=pd.read_csv(r'C:\ProjectFiles\cnn-image-retrieval\data\styles.csv', on_bad_lines="skip")

# %%
img_csv.isna().sum()
# Out:
# id                      0
# gender                  0
# masterCategory          0
# subCategory             0
# articleType             0
# baseColour             15
# season                 21
# year                    1
# usage                 317
# productDisplayName      7
# dtype: int64
